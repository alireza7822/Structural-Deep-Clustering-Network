# %% [markdown]
# <a href="https://colab.research.google.com/github/alireza7822/Structural-Deep-Clustering-Network/blob/main/SDCN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/bdy9527/SDCN.git
# Out:
# Cloning into 'SDCN'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 122 (delta 22), reused 1 (delta 0), pack-reused 81
# Receiving objects: 100% (122/122), 90.43 MiB | 14.49 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Updating files: 100% (41/41), done.

# %%
# %cd /content/SDCN
# Out:
# /content/SDCN

# %%
ls
# Out:
# calcu_graph.py  evaluation.py  graph/   README.md         SDCN.pdf  utils.py
# data/           GNN.py         LICENSE  requirements.txt  sdcn.py

# %%
# !pip install -r requirements.txt

# %%
# !pip install munkres
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python sdcn.py --name acm
# Out:
# use cuda: True
# Namespace(cuda=True, k=None, lr=0.001, n_clusters=3, n_input=1870, n_z=10, name='acm', pretrain_path='data/acm.pkl')
# SDCN(
#   (ae): AE(
#     (enc_1): Linear(in_features=1870, out_features=500, bias=True)
#     (enc_2): Linear(in_features=500, out_features=500, bias=True)
#     (enc_3): Linear(in_features=500, out_features=2000, bias=True)
#     (z_layer): Linear(in_features=2000, out_features=10, bias=True)
#     (dec_1): Linear(in_features=10, out_features=2000, bias=True)
#     (dec_2): Linear(in_features=2000, out_features=500, bias=True)
#     (dec_3): Linear(in_features=500, out_features=500, bias=True)
#     (x_bar_layer): Linear(in_features=500, out_features=1870, bias=True)
#   )
#   (gnn_1): GNNLayer()
#   (gnn_2): GNNLayer()
#   (gnn_3): GNNLayer()
#   (gnn_4): GNNLayer()
#   (gnn_5): GNNLayer()
# )
# pae :acc 0.8291 , nmi 0.5051 , ari 0.5581 , f1 0.8309
# 0Q :acc 0.8291 , nmi 0.5051 , ari 0.5581 , f1 0.8309
# ...
